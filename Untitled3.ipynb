# %% [markdown]
# <a href="https://colab.research.google.com/github/favas8606/machine-learning/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# data selection
data = pd.read_csv('BitcoinPrice.csv')

# %%
data.head()
# Out:
#                   Date        Price
# 0  2018-08-25 00:00:00  6719.429231
# 1  2018-08-26 00:00:00  6673.274167
# 2  2018-08-27 00:00:00  6719.266154
# 3  2018-08-28 00:00:00  7000.040000
# 4  2018-08-29 00:00:00  7054.276429

# %%
data = data.drop(['Date'],axis=1)

# %%
data
# Out:
#             Price
# 0     6719.429231
# 1     6673.274167
# 2     6719.266154
# 3     7000.040000
# 4     7054.276429
# ..            ...
# 360  10746.507692
# 361  10169.094167
# 362  10030.746667
# 363  10255.977500
# 364  10158.540833
#
# [365 rows x 1 columns]

# %%
# data pre prosessing
p_date = 30

# %%
data['Prediction'] = data[['Price']].shift(-p_date)

# %%
data.head()
# Out:
#          Price   Prediction
# 0  6719.429231  6639.304167
# 1  6673.274167  6412.459167
# 2  6719.266154  6468.631667
# 3  7000.040000  6535.476667
# 4  7054.276429  6677.342500

# %%
x = np.array(data.drop(['Prediction'],1))
x = x[: len(data) - p_date]

# %%
x.shape
# Out:
# (335, 1)

# %%
x

# %%
y = np.array(data['Prediction'])

# %%
y = y[: -p_date]

# %%
y.shape
# Out:
# (335,)

# %%
y

# %%
# model training
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
p_days_array = np.array(data.drop(['Prediction'], 1))[-p_date:]

# %%
p_days_array

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 1)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=1)

# %%
print('Random Forest Accuracy: {:.2f}%'.format(rf.score(x_test, y_test) * 100))
# Out:
# Random Forest Accuracy: 80.30%

# %%
# prediction
rf_predict = rf.predict(x_test)

# %%
rf_predict
# Out:
# array([ 6351.46114455,  9516.53605167,  7750.7555875 ,  3959.06149042,
#         3971.57947417, 11268.67978167,  3927.32389125,  6697.86227827,
#         4024.42655417, 10798.71147955,  4540.47900628, 10431.85859083,
#         5066.35391583,  3852.63272833,  3937.18549   ,  5351.59492045,
#         5033.18979583,  4132.5214475 , 11426.54671212,  4465.15508423,
#         4491.45026083, 10972.98194346, 10540.157475  ,  3882.15709962,
#         4269.2167225 ,  4738.5780075 ,  3654.24106   ,  8860.8707925 ,
#         3570.81020083,  6562.90198717,  4748.18488583,  8041.7443775 ,
#         5153.34248083,  3959.06149042,  4049.15822256,  3927.26477042,
#         4275.83217083, 10502.1318325 ,  6143.6344166 ,  3768.75331083,
#        10439.2297075 ,  5754.81591   ,  5842.97115667,  6988.81360417,
#         3941.64356583, 12213.95097244,  6193.31698865, 10145.58794833,
#         5660.94086   ,  3851.72116667,  4538.95673494,  6506.35002483,
# ...

# %%
y_test
# Out:
# array([ 6621.71166667, 11788.06916667,  7920.945     ,  4008.65833333,
#         3865.7975    , 11397.80166667,  3630.39666667,  5633.7475    ,
#         4000.335     ,  9708.43583333,  3589.26083333, 11703.73833333,
#         3832.92166667,  3832.61307692,  5310.17333333,  4106.87166667,
#         5076.3       ,  5465.515     , 10852.92666667,  3822.62666667,
#         8663.6425    , 11834.12416667, 11560.6025    ,  3426.19      ,
#         3458.70333333,  5255.61416667,  3604.1175    ,  6563.62833333,
#         6596.27615385,  7815.13583333,  3690.52333333,  6302.6125    ,
#         5527.80166667,  3631.55333333,  4103.45384615,  3610.74833333,
#         5197.75076923, 10230.73333333,  5718.22916667,  3749.56833333,
#        10255.9775    ,  4548.7975    ,  4293.84083333,  8727.90083333,
#         3579.89666667, 11779.45083333,  7265.96333333, 10158.54083333,
#         6488.82583333,  3842.13916667,  7941.22166667,  6412.45916667,
# ...

# %%
# model prediction for 30 days

# %%
rf_predict_30 = rf.predict(p_days_array)

# %%
rf_predict
# Out:
# array([ 6351.46114455,  9516.53605167,  7750.7555875 ,  3959.06149042,
#         3971.57947417, 11268.67978167,  3927.32389125,  6697.86227827,
#         4024.42655417, 10798.71147955,  4540.47900628, 10431.85859083,
#         5066.35391583,  3852.63272833,  3937.18549   ,  5351.59492045,
#         5033.18979583,  4132.5214475 , 11426.54671212,  4465.15508423,
#         4491.45026083, 10972.98194346, 10540.157475  ,  3882.15709962,
#         4269.2167225 ,  4738.5780075 ,  3654.24106   ,  8860.8707925 ,
#         3570.81020083,  6562.90198717,  4748.18488583,  8041.7443775 ,
#         5153.34248083,  3959.06149042,  4049.15822256,  3927.26477042,
#         4275.83217083, 10502.1318325 ,  6143.6344166 ,  3768.75331083,
#        10439.2297075 ,  5754.81591   ,  5842.97115667,  6988.81360417,
#         3941.64356583, 12213.95097244,  6193.31698865, 10145.58794833,
#         5660.94086   ,  3851.72116667,  4538.95673494,  6506.35002483,
# ...

# %%
data.head()
# Out:
#          Price   Prediction
# 0  6719.429231  6639.304167
# 1  6673.274167  6412.459167
# 2  6719.266154  6468.631667
# 3  7000.040000  6535.476667
# 4  7054.276429  6677.342500
